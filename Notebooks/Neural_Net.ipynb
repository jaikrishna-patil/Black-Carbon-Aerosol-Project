# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
df1=pd.read_csv("database.csv")

# %%
#q_abs

# %%
y = df1.iloc[:,25:26]
X = df1.iloc[:,:8]
y.head()
# Out:
#      q_abs
# 0  0.11691
# 1  0.15300
# 2  0.20060
# 3  0.23162
# 4  0.25746

# %%
X_train, X_test, y_train, y_test = train_test_split(
        X, y, 
        test_size=0.25, 
        random_state=42)
X_train.shape
# Out:
# (7370, 8)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['mean_absolute_percentage_error'])
NN_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 128)               1152
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 257
# ...
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 185/185 [==============================] - 0s 2ms/step - loss: 75.9144 - mean_absolute_percentage_error: 75.9144 - val_loss: 27.3013 - val_mean_absolute_percentage_error: 27.3013
# Epoch 2/500
# 185/185 [==============================] - 0s 2ms/step - loss: 24.7554 - mean_absolute_percentage_error: 24.7554 - val_loss: 17.3370 - val_mean_absolute_percentage_error: 17.3370
# Epoch 3/500
# 185/185 [==============================] - 0s 1ms/step - loss: 17.1167 - mean_absolute_percentage_error: 17.1167 - val_loss: 11.4357 - val_mean_absolute_percentage_error: 11.4357
# Epoch 4/500
# 185/185 [==============================] - 0s 1ms/step - loss: 12.5102 - mean_absolute_percentage_error: 12.5102 - val_loss: 10.7996 - val_mean_absolute_percentage_error: 10.7996
# Epoch 5/500
# 185/185 [==============================] - 0s 1ms/step - loss: 10.5206 - mean_absolute_percentage_error: 10.5206 - val_loss: 9.0167 - val_mean_absolute_percentage_error: 9.0167
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)

# %%
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.016363514944460145

# %%
#q_sca

# %%
y = df1.iloc[:,26:27]
X = df1.iloc[:,:8]
y.head()
# Out:
#       q_sca
# 0  0.000389
# 1  0.001005
# 2  0.002514
# 3  0.004187
# 4  0.005988

# %%
X_train, X_test, y_train, y_test = train_test_split(
        X, y, 
        test_size=0.25, 
        random_state=42)
X_train.shape
# Out:
# (7370, 8)

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# ...
# 185/185 [==============================] - 0s 2ms/step - loss: 8.9126 - mean_absolute_percentage_error: 8.9126 - val_loss: 10.5837 - val_mean_absolute_percentage_error: 10.5837
# Epoch 2/500
# 185/185 [==============================] - 0s 1ms/step - loss: 7.7663 - mean_absolute_percentage_error: 7.7663 - val_loss: 7.0129 - val_mean_absolute_percentage_error: 7.0129
# Epoch 3/500
# 185/185 [==============================] - 0s 1ms/step - loss: 8.4683 - mean_absolute_percentage_error: 8.4683 - val_loss: 10.2295 - val_mean_absolute_percentage_error: 10.2295
# Epoch 4/500
# 185/185 [==============================] - 0s 1ms/step - loss: 8.5732 - mean_absolute_percentage_error: 8.5732 - val_loss: 6.0075 - val_mean_absolute_percentage_error: 6.0075
# Epoch 5/500
# 185/185 [==============================] - 0s 1ms/step - loss: 7.3472 - mean_absolute_percentage_error: 7.3472 - val_loss: 6.7647 - val_mean_absolute_percentage_error: 6.7647
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.059673438484517

# %%
#g

# %%
y = df1.iloc[:,27:28]
X = df1.iloc[:,:8]
y.head()
# Out:
#           g
# 0  0.003798
# 1  0.008979
# 2  0.022970
# 3  0.037044
# 4  0.051049

# %%
X_train, X_test, y_train, y_test = train_test_split(
        X, y, 
        test_size=0.25, 
        random_state=42)
X_train.shape
# Out:
# (7370, 8)

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 185/185 [==============================] - 0s 2ms/step - loss: 18.4091 - mean_absolute_percentage_error: 18.4091 - val_loss: 11.9209 - val_mean_absolute_percentage_error: 11.9209
# Epoch 2/500
# 185/185 [==============================] - 0s 1ms/step - loss: 9.8136 - mean_absolute_percentage_error: 9.8136 - val_loss: 8.9064 - val_mean_absolute_percentage_error: 8.9064
# Epoch 3/500
# 185/185 [==============================] - 0s 1ms/step - loss: 7.8505 - mean_absolute_percentage_error: 7.8505 - val_loss: 7.2486 - val_mean_absolute_percentage_error: 7.2486
# Epoch 4/500
# 185/185 [==============================] - 0s 1ms/step - loss: 6.5899 - mean_absolute_percentage_error: 6.5899 - val_loss: 6.0562 - val_mean_absolute_percentage_error: 6.0562
# Epoch 5/500
# 185/185 [==============================] - 0s 1ms/step - loss: 6.8445 - mean_absolute_percentage_error: 6.8445 - val_loss: 7.2142 - val_mean_absolute_percentage_error: 7.2142
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.039737686990516045

# %% [markdown]
# # Leave fractal dimesnion: =2.2 as test set

# %%
train_set=df1[(df1['fractal_dimension']<=2.1) | (df1['fractal_dimension']>2.2)]
test_set=df1[df1['fractal_dimension']==2.2]
test_set.shape
# Out:
# (2195, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 191/191 [==============================] - 0s 1ms/step - loss: 14.7539 - mean_absolute_percentage_error: 14.7539 - val_loss: 8.6366 - val_mean_absolute_percentage_error: 8.6366
# Epoch 2/500
# 191/191 [==============================] - 0s 1ms/step - loss: 5.2885 - mean_absolute_percentage_error: 5.2885 - val_loss: 9.0578 - val_mean_absolute_percentage_error: 9.0578
# Epoch 3/500
# 191/191 [==============================] - 0s 1ms/step - loss: 3.5873 - mean_absolute_percentage_error: 3.5873 - val_loss: 6.0602 - val_mean_absolute_percentage_error: 6.0602
# Epoch 4/500
# 191/191 [==============================] - 0s 1ms/step - loss: 2.7268 - mean_absolute_percentage_error: 2.7268 - val_loss: 6.4280 - val_mean_absolute_percentage_error: 6.4280
# Epoch 5/500
# 191/191 [==============================] - 0s 1ms/step - loss: 2.6044 - mean_absolute_percentage_error: 2.6044 - val_loss: 5.1763 - val_mean_absolute_percentage_error: 5.1763
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.035159370333289454

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 191/191 [==============================] - 0s 1ms/step - loss: 85.2796 - mean_absolute_percentage_error: 85.2796 - val_loss: 59.0151 - val_mean_absolute_percentage_error: 59.0151
# Epoch 2/500
# 191/191 [==============================] - 0s 1ms/step - loss: 25.3131 - mean_absolute_percentage_error: 25.3131 - val_loss: 27.8596 - val_mean_absolute_percentage_error: 27.8596
# Epoch 3/500
# 191/191 [==============================] - 0s 1ms/step - loss: 20.5611 - mean_absolute_percentage_error: 20.5611 - val_loss: 23.8626 - val_mean_absolute_percentage_error: 23.8626
# Epoch 4/500
# 191/191 [==============================] - 0s 1ms/step - loss: 16.4519 - mean_absolute_percentage_error: 16.4519 - val_loss: 22.1233 - val_mean_absolute_percentage_error: 22.1233
# Epoch 5/500
# 191/191 [==============================] - 0s 1ms/step - loss: 17.1464 - mean_absolute_percentage_error: 17.1464 - val_loss: 27.0649 - val_mean_absolute_percentage_error: 27.0649
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.1017854800489867

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# ...
# 191/191 [==============================] - 0s 2ms/step - loss: 18.6769 - mean_absolute_percentage_error: 18.6769 - val_loss: 11.3505 - val_mean_absolute_percentage_error: 11.3505
# Epoch 2/500
# 191/191 [==============================] - 0s 1ms/step - loss: 8.9454 - mean_absolute_percentage_error: 8.9454 - val_loss: 10.4146 - val_mean_absolute_percentage_error: 10.4146
# Epoch 3/500
# 191/191 [==============================] - 0s 1ms/step - loss: 7.3068 - mean_absolute_percentage_error: 7.3068 - val_loss: 10.3204 - val_mean_absolute_percentage_error: 10.3204
# Epoch 4/500
# 191/191 [==============================] - 0s 1ms/step - loss: 7.0473 - mean_absolute_percentage_error: 7.0473 - val_loss: 10.2910 - val_mean_absolute_percentage_error: 10.2910
# Epoch 5/500
# 191/191 [==============================] - 0s 1ms/step - loss: 6.7989 - mean_absolute_percentage_error: 6.7989 - val_loss: 8.7046 - val_mean_absolute_percentage_error: 8.7046
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.04893886968222961

# %% [markdown]
# # Leave fractal dimesnion: =2.1, 2.2 as test set

# %%
train_set=df1[(df1['fractal_dimension']<2.1) | (df1['fractal_dimension']>2.2)]
test_set=df1[(df1['fractal_dimension']==2.1) | (df1['fractal_dimension']==2.2)]
test_set.shape
# Out:
# (2968, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 172/172 [==============================] - 0s 1ms/step - loss: 19.5130 - mean_absolute_percentage_error: 19.5130 - val_loss: 11.1146 - val_mean_absolute_percentage_error: 11.1146
# Epoch 2/500
# 172/172 [==============================] - 0s 1ms/step - loss: 8.3750 - mean_absolute_percentage_error: 8.3750 - val_loss: 8.9149 - val_mean_absolute_percentage_error: 8.9149
# Epoch 3/500
# 172/172 [==============================] - 0s 1ms/step - loss: 5.4409 - mean_absolute_percentage_error: 5.4409 - val_loss: 7.4909 - val_mean_absolute_percentage_error: 7.4909
# Epoch 4/500
# 172/172 [==============================] - 0s 1ms/step - loss: 4.2879 - mean_absolute_percentage_error: 4.2879 - val_loss: 8.1963 - val_mean_absolute_percentage_error: 8.1963
# Epoch 5/500
# 172/172 [==============================] - 0s 1ms/step - loss: 3.9338 - mean_absolute_percentage_error: 3.9338 - val_loss: 6.9085 - val_mean_absolute_percentage_error: 6.9085
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.024392394713274524

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 172/172 [==============================] - 0s 2ms/step - loss: 74.4750 - mean_absolute_percentage_error: 74.4750 - val_loss: 32.1884 - val_mean_absolute_percentage_error: 32.1884
# Epoch 2/500
# 172/172 [==============================] - 0s 1ms/step - loss: 23.2004 - mean_absolute_percentage_error: 23.2004 - val_loss: 26.2985 - val_mean_absolute_percentage_error: 26.2985
# Epoch 3/500
# 172/172 [==============================] - 0s 1ms/step - loss: 18.9659 - mean_absolute_percentage_error: 18.9659 - val_loss: 26.9238 - val_mean_absolute_percentage_error: 26.9238
# Epoch 4/500
# 172/172 [==============================] - 0s 1ms/step - loss: 17.8907 - mean_absolute_percentage_error: 17.8907 - val_loss: 23.0402 - val_mean_absolute_percentage_error: 23.0402
# Epoch 5/500
# 172/172 [==============================] - 0s 1ms/step - loss: 16.6898 - mean_absolute_percentage_error: 16.6898 - val_loss: 23.4166 - val_mean_absolute_percentage_error: 23.4166
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.10394815012726365

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 172/172 [==============================] - 0s 2ms/step - loss: 22.3025 - mean_absolute_percentage_error: 22.3025 - val_loss: 17.7647 - val_mean_absolute_percentage_error: 17.7647
# Epoch 2/500
# 172/172 [==============================] - 0s 1ms/step - loss: 8.7798 - mean_absolute_percentage_error: 8.7798 - val_loss: 9.7878 - val_mean_absolute_percentage_error: 9.7878
# Epoch 3/500
# 172/172 [==============================] - 0s 1ms/step - loss: 6.5716 - mean_absolute_percentage_error: 6.5716 - val_loss: 8.9405 - val_mean_absolute_percentage_error: 8.9405
# Epoch 4/500
# 172/172 [==============================] - 0s 1ms/step - loss: 6.1984 - mean_absolute_percentage_error: 6.1984 - val_loss: 8.0963 - val_mean_absolute_percentage_error: 8.0963
# Epoch 5/500
# 172/172 [==============================] - 0s 1ms/step - loss: 5.8847 - mean_absolute_percentage_error: 5.8847 - val_loss: 9.1450 - val_mean_absolute_percentage_error: 9.1450
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.05436893487590062

# %% [markdown]
# # Leave fraction of coating: ==50 as test set

# %%
train_set=df1[(df1['fraction_of_coating']<=40) | (df1['fraction_of_coating']>50)]
test_set=df1[df1['fraction_of_coating']==50]
test_set.shape
# Out:
# (1264, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 215/215 [==============================] - 0s 1ms/step - loss: 1.7364 - mean_absolute_percentage_error: 1.7364 - val_loss: 8.0918 - val_mean_absolute_percentage_error: 8.0918
# Epoch 2/500
# 215/215 [==============================] - 0s 1ms/step - loss: 1.7482 - mean_absolute_percentage_error: 1.7482 - val_loss: 7.7423 - val_mean_absolute_percentage_error: 7.7423
# Epoch 3/500
# 215/215 [==============================] - 0s 1ms/step - loss: 1.7406 - mean_absolute_percentage_error: 1.7406 - val_loss: 6.0909 - val_mean_absolute_percentage_error: 6.0909
# Epoch 4/500
# 215/215 [==============================] - 0s 1ms/step - loss: 1.6599 - mean_absolute_percentage_error: 1.6599 - val_loss: 8.4633 - val_mean_absolute_percentage_error: 8.4633
# Epoch 5/500
# 215/215 [==============================] - 0s 1ms/step - loss: 2.7673 - mean_absolute_percentage_error: 2.7673 - val_loss: 6.3809 - val_mean_absolute_percentage_error: 6.3809
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.018359388305196223

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 215/215 [==============================] - 0s 1ms/step - loss: 72.1517 - mean_absolute_percentage_error: 72.1517 - val_loss: 28.5001 - val_mean_absolute_percentage_error: 28.5001
# Epoch 2/500
# 215/215 [==============================] - 0s 1ms/step - loss: 24.5815 - mean_absolute_percentage_error: 24.5815 - val_loss: 31.0840 - val_mean_absolute_percentage_error: 31.0840
# Epoch 3/500
# 215/215 [==============================] - 0s 1ms/step - loss: 19.7717 - mean_absolute_percentage_error: 19.7717 - val_loss: 29.7952 - val_mean_absolute_percentage_error: 29.7952
# Epoch 4/500
# 215/215 [==============================] - 0s 1ms/step - loss: 19.8828 - mean_absolute_percentage_error: 19.8828 - val_loss: 30.1795 - val_mean_absolute_percentage_error: 30.1795
# Epoch 5/500
# 215/215 [==============================] - 0s 1ms/step - loss: 17.4225 - mean_absolute_percentage_error: 17.4225 - val_loss: 29.2978 - val_mean_absolute_percentage_error: 29.2978
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.0839771248940288

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 215/215 [==============================] - 0s 1ms/step - loss: 19.4637 - mean_absolute_percentage_error: 19.4637 - val_loss: 12.7977 - val_mean_absolute_percentage_error: 12.7977
# Epoch 2/500
# 215/215 [==============================] - 0s 1ms/step - loss: 12.3803 - mean_absolute_percentage_error: 12.3803 - val_loss: 13.2503 - val_mean_absolute_percentage_error: 13.2503
# Epoch 3/500
# 215/215 [==============================] - 0s 1ms/step - loss: 11.0644 - mean_absolute_percentage_error: 11.0644 - val_loss: 10.6193 - val_mean_absolute_percentage_error: 10.6193
# Epoch 4/500
# 215/215 [==============================] - 0s 1ms/step - loss: 9.7986 - mean_absolute_percentage_error: 9.7986 - val_loss: 10.7379 - val_mean_absolute_percentage_error: 10.7379
# Epoch 5/500
# 215/215 [==============================] - 0s 1ms/step - loss: 9.1899 - mean_absolute_percentage_error: 9.1899 - val_loss: 16.1122 - val_mean_absolute_percentage_error: 16.1122
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.04693535014138639

# %% [markdown]
# # Leave fraction of coating: ==40, 50 as test set

# %%
train_set=df1[(df1['fraction_of_coating']<40) | (df1['fraction_of_coating']>50)]
test_set=df1[(df1['fraction_of_coating']==40) | (df1['fraction_of_coating']==50)]
test_set.shape
# Out:
# (1580, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 207/207 [==============================] - 0s 1ms/step - loss: 18.7955 - mean_absolute_percentage_error: 18.7955 - val_loss: 11.5192 - val_mean_absolute_percentage_error: 11.5192
# Epoch 2/500
# 207/207 [==============================] - 0s 1ms/step - loss: 5.9167 - mean_absolute_percentage_error: 5.9167 - val_loss: 8.5104 - val_mean_absolute_percentage_error: 8.5104
# Epoch 3/500
# 207/207 [==============================] - 0s 1ms/step - loss: 4.7395 - mean_absolute_percentage_error: 4.7395 - val_loss: 13.6231 - val_mean_absolute_percentage_error: 13.6231
# Epoch 4/500
# 207/207 [==============================] - 0s 1ms/step - loss: 4.2617 - mean_absolute_percentage_error: 4.2617 - val_loss: 6.4647 - val_mean_absolute_percentage_error: 6.4647
# Epoch 5/500
# 207/207 [==============================] - 0s 1ms/step - loss: 3.9282 - mean_absolute_percentage_error: 3.9282 - val_loss: 7.5524 - val_mean_absolute_percentage_error: 7.5524
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.011958844088109728

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 207/207 [==============================] - 0s 1ms/step - loss: 61.7507 - mean_absolute_percentage_error: 61.7507 - val_loss: 24.1526 - val_mean_absolute_percentage_error: 24.1526
# Epoch 2/500
# 207/207 [==============================] - 0s 1ms/step - loss: 15.7512 - mean_absolute_percentage_error: 15.7512 - val_loss: 20.5570 - val_mean_absolute_percentage_error: 20.5570
# Epoch 3/500
# 207/207 [==============================] - 0s 1ms/step - loss: 12.4799 - mean_absolute_percentage_error: 12.4799 - val_loss: 17.5079 - val_mean_absolute_percentage_error: 17.5079
# Epoch 4/500
# 207/207 [==============================] - 0s 1ms/step - loss: 10.4526 - mean_absolute_percentage_error: 10.4526 - val_loss: 19.1125 - val_mean_absolute_percentage_error: 19.1125
# Epoch 5/500
# 207/207 [==============================] - 0s 1ms/step - loss: 9.7484 - mean_absolute_percentage_error: 9.7484 - val_loss: 23.1475 - val_mean_absolute_percentage_error: 23.1475
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.06175863512322355

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 207/207 [==============================] - 0s 2ms/step - loss: 18.5614 - mean_absolute_percentage_error: 18.5614 - val_loss: 14.5720 - val_mean_absolute_percentage_error: 14.5720
# Epoch 2/500
# 207/207 [==============================] - 0s 2ms/step - loss: 9.2340 - mean_absolute_percentage_error: 9.2340 - val_loss: 11.5237 - val_mean_absolute_percentage_error: 11.5237
# Epoch 3/500
# 207/207 [==============================] - 0s 1ms/step - loss: 8.0652 - mean_absolute_percentage_error: 8.0652 - val_loss: 11.2466 - val_mean_absolute_percentage_error: 11.2466
# Epoch 4/500
# 207/207 [==============================] - 0s 1ms/step - loss: 6.8559 - mean_absolute_percentage_error: 6.8559 - val_loss: 9.1477 - val_mean_absolute_percentage_error: 9.1477
# Epoch 5/500
# 207/207 [==============================] - 0s 1ms/step - loss: 6.3998 - mean_absolute_percentage_error: 6.3998 - val_loss: 8.8255 - val_mean_absolute_percentage_error: 8.8255
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.04169676462831125

# %% [markdown]
# # Leave fraction of coating: ==40, 50, 60 as test set

# %%
train_set=df1[(df1['fraction_of_coating']<40) | (df1['fraction_of_coating']>60)]
test_set=df1[(df1['fraction_of_coating']>=40) & (df1['fraction_of_coating']<=60)]
test_set.shape
# Out:
# (1896, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 199/199 [==============================] - 0s 1ms/step - loss: 18.2528 - mean_absolute_percentage_error: 18.2528 - val_loss: 14.0803 - val_mean_absolute_percentage_error: 14.0803
# Epoch 2/500
# 199/199 [==============================] - 0s 1ms/step - loss: 7.0843 - mean_absolute_percentage_error: 7.0843 - val_loss: 12.3126 - val_mean_absolute_percentage_error: 12.3126
# Epoch 3/500
# 199/199 [==============================] - 0s 1ms/step - loss: 5.4943 - mean_absolute_percentage_error: 5.4943 - val_loss: 10.8855 - val_mean_absolute_percentage_error: 10.8855
# Epoch 4/500
# 199/199 [==============================] - 0s 1ms/step - loss: 4.6214 - mean_absolute_percentage_error: 4.6214 - val_loss: 9.3813 - val_mean_absolute_percentage_error: 9.3813
# Epoch 5/500
# 199/199 [==============================] - 0s 1ms/step - loss: 4.2771 - mean_absolute_percentage_error: 4.2771 - val_loss: 8.4810 - val_mean_absolute_percentage_error: 8.4810
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.01269019737939256

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 199/199 [==============================] - 0s 1ms/step - loss: 90.4937 - mean_absolute_percentage_error: 90.4937 - val_loss: 35.8095 - val_mean_absolute_percentage_error: 35.8095
# Epoch 2/500
# 199/199 [==============================] - 0s 1ms/step - loss: 26.1501 - mean_absolute_percentage_error: 26.1501 - val_loss: 19.6640 - val_mean_absolute_percentage_error: 19.6640
# Epoch 3/500
# 199/199 [==============================] - 0s 1ms/step - loss: 14.7625 - mean_absolute_percentage_error: 14.7625 - val_loss: 18.2515 - val_mean_absolute_percentage_error: 18.2515
# Epoch 4/500
# 199/199 [==============================] - 0s 1ms/step - loss: 12.3087 - mean_absolute_percentage_error: 12.3087 - val_loss: 13.7543 - val_mean_absolute_percentage_error: 13.7543
# Epoch 5/500
# 199/199 [==============================] - 0s 1ms/step - loss: 10.3571 - mean_absolute_percentage_error: 10.3571 - val_loss: 11.8001 - val_mean_absolute_percentage_error: 11.8001
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.060978351948877116

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 199/199 [==============================] - 0s 1ms/step - loss: 19.9607 - mean_absolute_percentage_error: 19.9607 - val_loss: 15.1700 - val_mean_absolute_percentage_error: 15.1700
# Epoch 2/500
# 199/199 [==============================] - 0s 1ms/step - loss: 11.7109 - mean_absolute_percentage_error: 11.7109 - val_loss: 17.1425 - val_mean_absolute_percentage_error: 17.1425
# Epoch 3/500
# 199/199 [==============================] - 0s 1ms/step - loss: 9.1490 - mean_absolute_percentage_error: 9.1490 - val_loss: 10.1207 - val_mean_absolute_percentage_error: 10.1207
# Epoch 4/500
# 199/199 [==============================] - 0s 1ms/step - loss: 7.7310 - mean_absolute_percentage_error: 7.7310 - val_loss: 9.1056 - val_mean_absolute_percentage_error: 9.1056
# Epoch 5/500
# 199/199 [==============================] - 0s 1ms/step - loss: 6.4879 - mean_absolute_percentage_error: 6.4879 - val_loss: 10.9778 - val_mean_absolute_percentage_error: 10.9778
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.03527911230251923

# %% [markdown]
# # Leave wavelength = 467 out

# %%
train_set=df1[df1['wavelength']>467]
test_set=df1[df1['wavelength']==467]
test_set.shape
# Out:
# (3014, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 171/171 [==============================] - 0s 1ms/step - loss: 19.5888 - mean_absolute_percentage_error: 19.5888 - val_loss: 9.8998 - val_mean_absolute_percentage_error: 9.8998
# Epoch 2/500
# 171/171 [==============================] - 0s 1ms/step - loss: 5.9830 - mean_absolute_percentage_error: 5.9830 - val_loss: 10.6385 - val_mean_absolute_percentage_error: 10.6385
# Epoch 3/500
# 171/171 [==============================] - 0s 1ms/step - loss: 4.2288 - mean_absolute_percentage_error: 4.2288 - val_loss: 6.1001 - val_mean_absolute_percentage_error: 6.1001
# Epoch 4/500
# 171/171 [==============================] - 0s 1ms/step - loss: 3.4627 - mean_absolute_percentage_error: 3.4627 - val_loss: 6.2685 - val_mean_absolute_percentage_error: 6.2685
# Epoch 5/500
# 171/171 [==============================] - 0s 1ms/step - loss: 3.2635 - mean_absolute_percentage_error: 3.2635 - val_loss: 5.9470 - val_mean_absolute_percentage_error: 5.9470
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.17031252204310235

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 171/171 [==============================] - 0s 2ms/step - loss: 63.8715 - mean_absolute_percentage_error: 63.8715 - val_loss: 36.1534 - val_mean_absolute_percentage_error: 36.1534
# Epoch 2/500
# 171/171 [==============================] - 0s 1ms/step - loss: 21.7965 - mean_absolute_percentage_error: 21.7965 - val_loss: 42.4948 - val_mean_absolute_percentage_error: 42.4948
# Epoch 3/500
# 171/171 [==============================] - 0s 1ms/step - loss: 20.4202 - mean_absolute_percentage_error: 20.4202 - val_loss: 39.6147 - val_mean_absolute_percentage_error: 39.6147
# Epoch 4/500
# 171/171 [==============================] - 0s 1ms/step - loss: 17.7736 - mean_absolute_percentage_error: 17.7736 - val_loss: 36.6485 - val_mean_absolute_percentage_error: 36.6485
# Epoch 5/500
# 171/171 [==============================] - 0s 1ms/step - loss: 14.2622 - mean_absolute_percentage_error: 14.2622 - val_loss: 32.4750 - val_mean_absolute_percentage_error: 32.4750
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.25129863278267733

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 171/171 [==============================] - 0s 2ms/step - loss: 27.1215 - mean_absolute_percentage_error: 27.1215 - val_loss: 27.1641 - val_mean_absolute_percentage_error: 27.1641
# Epoch 2/500
# 171/171 [==============================] - 0s 1ms/step - loss: 19.6723 - mean_absolute_percentage_error: 19.6723 - val_loss: 28.7743 - val_mean_absolute_percentage_error: 28.7743
# Epoch 3/500
# 171/171 [==============================] - 0s 1ms/step - loss: 16.8238 - mean_absolute_percentage_error: 16.8238 - val_loss: 25.4169 - val_mean_absolute_percentage_error: 25.4169
# Epoch 4/500
# 171/171 [==============================] - 0s 1ms/step - loss: 13.0158 - mean_absolute_percentage_error: 13.0158 - val_loss: 26.6357 - val_mean_absolute_percentage_error: 26.6357
# Epoch 5/500
# 171/171 [==============================] - 0s 1ms/step - loss: 10.9740 - mean_absolute_percentage_error: 10.9740 - val_loss: 21.7316 - val_mean_absolute_percentage_error: 21.7316
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.09326374664353951

# %% [markdown]
# # Leave wavelength = 530 out

# %%
train_set=df1[(df1['wavelength']==467) | (df1['wavelength']==660)]
test_set=df1[df1['wavelength']==530]
train_set.shape
# Out:
# (6446, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 162/162 [==============================] - 0s 2ms/step - loss: 90.5683 - mean_absolute_percentage_error: 90.5683 - val_loss: 53.2318 - val_mean_absolute_percentage_error: 53.2318
# Epoch 2/500
# 162/162 [==============================] - 0s 1ms/step - loss: 27.8011 - mean_absolute_percentage_error: 27.8011 - val_loss: 35.9383 - val_mean_absolute_percentage_error: 35.9383
# Epoch 3/500
# 162/162 [==============================] - 0s 1ms/step - loss: 22.4971 - mean_absolute_percentage_error: 22.4971 - val_loss: 10.8463 - val_mean_absolute_percentage_error: 10.8463
# Epoch 4/500
# 162/162 [==============================] - 0s 1ms/step - loss: 15.7102 - mean_absolute_percentage_error: 15.7102 - val_loss: 9.2729 - val_mean_absolute_percentage_error: 9.2729
# Epoch 5/500
# 162/162 [==============================] - 0s 1ms/step - loss: 13.4620 - mean_absolute_percentage_error: 13.4620 - val_loss: 5.5646 - val_mean_absolute_percentage_error: 5.5646
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.31081854367711337

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 162/162 [==============================] - 0s 1ms/step - loss: 84.7055 - mean_absolute_percentage_error: 84.7055 - val_loss: 35.2705 - val_mean_absolute_percentage_error: 35.2705
# Epoch 2/500
# 162/162 [==============================] - 0s 1ms/step - loss: 25.1325 - mean_absolute_percentage_error: 25.1325 - val_loss: 35.0962 - val_mean_absolute_percentage_error: 35.0962
# Epoch 3/500
# 162/162 [==============================] - 0s 1ms/step - loss: 23.0407 - mean_absolute_percentage_error: 23.0407 - val_loss: 37.9132 - val_mean_absolute_percentage_error: 37.9132
# Epoch 4/500
# 162/162 [==============================] - 0s 1ms/step - loss: 21.7872 - mean_absolute_percentage_error: 21.7872 - val_loss: 32.6240 - val_mean_absolute_percentage_error: 32.6240
# Epoch 5/500
# 162/162 [==============================] - 0s 1ms/step - loss: 21.8142 - mean_absolute_percentage_error: 21.8142 - val_loss: 29.6109 - val_mean_absolute_percentage_error: 29.6109
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.15898315462849208

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Epoch 1/500
# 162/162 [==============================] - 0s 1ms/step - loss: 25.1889 - mean_absolute_percentage_error: 25.1889 - val_loss: 32.9960 - val_mean_absolute_percentage_error: 32.9960
# Epoch 2/500
# 162/162 [==============================] - 0s 1ms/step - loss: 16.5472 - mean_absolute_percentage_error: 16.5472 - val_loss: 26.0373 - val_mean_absolute_percentage_error: 26.0373
# Epoch 3/500
# 162/162 [==============================] - 0s 1ms/step - loss: 13.9535 - mean_absolute_percentage_error: 13.9535 - val_loss: 26.5169 - val_mean_absolute_percentage_error: 26.5169
# Epoch 4/500
# 162/162 [==============================] - 0s 1ms/step - loss: 11.2918 - mean_absolute_percentage_error: 11.2918 - val_loss: 20.2277 - val_mean_absolute_percentage_error: 20.2277
# Epoch 5/500
# 162/162 [==============================] - 0s 1ms/step - loss: 9.8832 - mean_absolute_percentage_error: 9.8832 - val_loss: 21.3478 - val_mean_absolute_percentage_error: 21.3478
# Epoch 6/500
# ...

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.09462386335371219

# %% [markdown]
# # Extrapolation

# %% [markdown]
# # Leave fractal dimesnion: =2.8 as test set

# %%
train_set=df1[(df1['fractal_dimension']<2.8)]
test_set=df1[df1['fractal_dimension']==2.8]
test_set.shape
# Out:
# (92, 36)

# %%
#q_abs

# %%
y_train = train_set.iloc[:,25:26]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,25:26]
X_test = test_set.iloc[:,:8]

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['mean_absolute_percentage_error'])
NN_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# ...
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint('Weights-{epoch:03d}--{val_loss:.5f}.hdf5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')

# %%
history=NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2, callbacks=[checkpoint])
# Out:
# Epoch 1/500
# 238/241 [============================>.] - ETA: 0s - loss: 62.3341 - mean_absolute_percentage_error: 62.3341
# Epoch 00001: val_loss improved from inf to 33.62343, saving model to Weights-001--33.62343.hdf5
# 241/241 [==============================] - 0s 2ms/step - loss: 61.8832 - mean_absolute_percentage_error: 61.8832 - val_loss: 33.6234 - val_mean_absolute_percentage_error: 33.6234
# Epoch 2/500
# 237/241 [============================>.] - ETA: 0s - loss: 16.1869 - mean_absolute_percentage_error: 16.1869 ETA: 0s - loss: 18.3334 - mean_absolute_percentage_error: 18.
# Epoch 00002: val_loss improved from 33.62343 to 15.25757, saving model to Weights-002--15.25757.hdf5
# 241/241 [==============================] - 0s 1ms/step - loss: 16.0861 - mean_absolute_percentage_error: 16.0861 - val_loss: 15.2576 - val_mean_absolute_percentage_error: 15.2576
# Epoch 3/500
# 233/241 [============================>.] - ETA: 0s - loss: 11.1284 - mean_absolute_percentage_error: 11.1284
# ...

# %%
weights_file = 'Weights-094--2.97304.hdf5' # choose the best checkpoint 
NN_model.load_weights(weights_file) # load it
NN_model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['mean_absolute_percentage_error'])

# %%
# evaluate the model
_, train_acc = NN_model.evaluate(X_train, y_train, verbose=0)
_, test_acc = NN_model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend()
plt.show()
# Out:
# Train: 1.561, Test: 2.460

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.024600992440974582

# %%
#q_sca

# %%
y_train = train_set.iloc[:,26:27]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,26:27]
X_test = test_set.iloc[:,:8]

# %%
checkpoint = ModelCheckpoint('Wights-{epoch:03d}--{val_loss:.5f}.hdf5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')

# %%
history=NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2, callbacks=[checkpoint])
# Out:
# Epoch 1/500
# 238/241 [============================>.] - ETA: 0s - loss: 114.9666 - mean_absolute_percentage_error: 114.9666
# Epoch 00001: val_loss improved from inf to 40.51743, saving model to Wights-001--40.51743.hdf5
# 241/241 [==============================] - 0s 1ms/step - loss: 114.2015 - mean_absolute_percentage_error: 114.2015 - val_loss: 40.5174 - val_mean_absolute_percentage_error: 40.5174
# Epoch 2/500
# 237/241 [============================>.] - ETA: 0s - loss: 42.8973 - mean_absolute_percentage_error: 42.8973
# Epoch 00002: val_loss did not improve from 40.51743
# 241/241 [==============================] - 0s 1ms/step - loss: 42.7746 - mean_absolute_percentage_error: 42.7746 - val_loss: 47.3077 - val_mean_absolute_percentage_error: 47.3077
# Epoch 3/500
# 236/241 [============================>.] - ETA: 0s - loss: 32.5530 - mean_absolute_percentage_error: 32.5530
# Epoch 00003: val_loss improved from 40.51743 to 31.80475, saving model to Wights-003--31.80475.hdf5
# ...

# %%
weights_file = 'Wights-288--11.50930.hdf5' # choose the best checkpoint 
NN_model.load_weights(weights_file) # load it
NN_model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['mean_absolute_percentage_error'])

# %%
# evaluate the model
_, train_acc = NN_model.evaluate(X_train, y_train, verbose=0)
_, test_acc = NN_model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend()
plt.show()
# Out:
# Train: 7.882, Test: 14.467

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.14466584246755235

# %%
#g

# %%
y_train = train_set.iloc[:,27:28]
X_train = train_set.iloc[:,:8]
y_test = test_set.iloc[:,27:28]
X_test = test_set.iloc[:,:8]

# %%
checkpoint = ModelCheckpoint('Wghts-{epoch:03d}--{val_loss:.5f}.hdf5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')

# %%
history=NN_model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2, callbacks=[checkpoint])
# Out:
# Epoch 1/500
# 239/241 [============================>.] - ETA: 0s - loss: 20.2725 - mean_absolute_percentage_error: 20.2725WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 16.62119, saving model to Wghts-001--16.62119.hdf5
# 241/241 [==============================] - 0s 2ms/step - loss: 20.2309 - mean_absolute_percentage_error: 20.2309 - val_loss: 16.6212 - val_mean_absolute_percentage_error: 16.6212
# Epoch 2/500
# 230/241 [===========================>..] - ETA: 0s - loss: 14.0145 - mean_absolute_percentage_error: 14.0145
# Epoch 00002: val_loss improved from 16.62119 to 15.79347, saving model to Wghts-002--15.79347.hdf5
# 241/241 [==============================] - 0s 1ms/step - loss: 13.8991 - mean_absolute_percentage_error: 13.8991 - val_loss: 15.7935 - val_mean_absolute_percentage_error: 15.7935
# Epoch 3/500
# ...

# %%
weights_file = 'Wghts-473--4.60557.hdf5' # choose the best checkpoint 
NN_model.load_weights(weights_file) # load it
NN_model.compile(loss='mean_absolute_percentage_error', optimizer='adam', metrics=['mean_absolute_percentage_error'])

# %%
# evaluate the model
_, train_acc = NN_model.evaluate(X_train, y_train, verbose=0)
_, test_acc = NN_model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend()
plt.show()
# Out:
# Train: 3.045, Test: 4.916

# %%
y_pred = NN_model.predict(X_test)
error= mean_absolute_percentage_error(y_test, y_pred)   
print('Mean absolute percentage error on test set: ', error)
# Out:
# Mean absolute percentage error on test set:  0.04915877886681157
